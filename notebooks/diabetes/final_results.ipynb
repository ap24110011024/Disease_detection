# %% [markdown]
# # Final Results Table
#
# This notebook consolidates the final performance metrics of all baseline
# machine learning models evaluated on the Pima Diabetes dataset.
#
# The generated `canonical_baseline_results.csv` serves as the official baseline
# used by:
# - Ablation Study
# - README
# - Research Paper
# - Cross-model comparisons

# %%
import pandas as pd

results = pd.DataFrame({

    "model":[
        "Logistic Regression",
        "Decision Tree",
        "Random Forest",
        "Support Vector Machine",
        "Multi-Layer Perceptron"
    ],

    "accuracy":[
        0.7143,
        0.7692,
        0.7468,
        0.7208,
        0.7532
    ],

    "precision":[
        0.6087,
        0.6842,
        0.6531,
        0.6341,
        0.6818
    ],

    "recall":[
        0.5185,
        0.6111,
        0.5926,
        0.4815,
        0.5556
    ],

    "f1":[
        0.5600,
        0.6452,
        0.6214,
        0.5474,
        0.6122
    ],

    "auc_roc":[
        0.8230,
        0.8056,
        0.8143,
        0.7970,
        0.8467
    ]

})

results
# Out:
#                     model  accuracy  precision  recall      f1  auc_roc
# 0     Logistic Regression    0.7143     0.6087  0.5185  0.5600   0.8230
# 1           Decision Tree    0.6948     0.6667  0.2593  0.3733   0.7881
# 2           Random Forest    0.7468     0.6531  0.5926  0.6214   0.8143
# 3  Support Vector Machine    0.7662     0.6863  0.6364  0.6604   0.7374
# 4  Multi-Layer Perceptron    0.7532     0.6818  0.5556  0.6122   0.8467

# %%
results.to_csv(
    "../../results/canonical_baseline_results.csv",
    index=False
)

print("Saved successfully!")
# Out:
# Saved successfully!

# %%
import pandas as pd

proposed_results = pd.read_csv(
    "../../results/week5/canonical_ablation_results.csv"
)

proposed_results = proposed_results.round({
    "Accuracy": 4,
    "Precision": 4,
    "Recall": 4,
    "F1 Score": 4
})

proposed_results
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2
# ----> 3 proposed_results = pd.read_csv(
#       4     "../../results/week5/ablation_results.csv"
#       5 )
#       6
#
# File ~/Desktop/Disease_detection/tf_env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/Disease_detection/tf_env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/Desktop/Disease_detection/tf_env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/Desktop/Disease_detection/tf_env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~/Desktop/Disease_detection/tf_env/lib/python3.12/site-packages/pandas/io/common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../results/week5/ablation_results.csv'

# %%
import os

os.makedirs("../../results", exist_ok=True)

proposed_results.to_csv(
    "../../results/proposed_framework_results.csv",
    index=False
)

print("Proposed framework results saved successfully!")
# Out:
# Proposed framework results saved successfully!
