# %% [markdown]
# # Final Results Table
#
# This notebook consolidates the final performance metrics of all baseline
# machine learning models evaluated on the Pima Diabetes dataset.
#
# The generated `final_results_table.csv` serves as the official baseline
# used by:
# - Ablation Study
# - README
# - Research Paper
# - Cross-model comparisons

# %%
import pandas as pd

results = pd.DataFrame({

    "model":[
        "Logistic Regression",
        "Decision Tree",
        "Random Forest",
        "Support Vector Machine",
        "Multi-Layer Perceptron"
    ],

    "accuracy":[
        0.7143,
        0.6948,
        0.7468,
        0.7662,
        0.7468
    ],

    "precision":[
        0.6087,
        0.6667,
        0.6531,
        0.6863,
        0.6415
    ],

    "recall":[
        0.5185,
        0.2593,
        0.5926,
        0.6364,
        0.6296
    ],

    "f1":[
        0.5600,
        0.3733,
        0.6214,
        0.6604,
        0.6355
    ],

    "auc_roc":[
        0.8230,
        0.7881,
        0.8143,
        0.7374,
        0.8439
    ]

})

results
# Out:
#                     model  accuracy  precision  recall      f1  auc_roc
# 0     Logistic Regression    0.7143     0.6087  0.5185  0.5600   0.8230
# 1           Decision Tree    0.6948     0.6667  0.2593  0.3733   0.7881
# 2           Random Forest    0.7468     0.6531  0.5926  0.6214   0.8143
# 3  Support Vector Machine    0.7662     0.6863  0.6364  0.6604   0.7374
# 4  Multi-Layer Perceptron    0.7468     0.6415  0.6296  0.6355   0.8439

# %%
results.to_csv(
    "../../results/final_results_table.csv",
    index=False
)

print("Saved successfully!")
# Out:
# Saved successfully!

# %%
results.to_csv(
    "../../results/final_results_table.csv",
    index=False
)

print("Final Results Table saved.")
# Out:
# Final Results Table saved.

# %%
import pandas as pd

proposed_results = pd.read_csv(
    "../../results/week5/ablation_results.csv"
)

proposed_results = proposed_results.round({
    "Accuracy": 4,
    "Precision": 4,
    "Recall": 4,
    "F1 Score": 4
})

proposed_results
# Out:
#           Configuration  Accuracy  Precision  Recall  F1 Score
# 0            Static MLP    0.7468     0.6415  0.6296    0.6355
# 1          Adaptive MLP    0.7318     0.6635  0.4655    0.5232
# 2  Adaptive + Proactive    0.6500     0.4853  0.8046    0.5979

# %%
import os

os.makedirs("../../results", exist_ok=True)

proposed_results.to_csv(
    "../../results/proposed_framework_results.csv",
    index=False
)

print("Proposed framework results saved successfully!")
# Out:
# Proposed framework results saved successfully!
